# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df_2021 = pd.read_csv('verkehrsmittelwahl2021.csv', delimiter=';')

# %%
df_2021.head()
# Out:
#   NUTS1 NUTS2  NUTS3  DISTRICT_CODE  SUB_DISTRICT_CODE  YEAR  REF_YEAR  \
# 0   AT1  AT13  AT130          90001                  0  2005      2021
# 1   AT1  AT13  AT130          90001                  0  2006      2021
# 2   AT1  AT13  AT130          90001                  0  2007      2021
# 3   AT1  AT13  AT130          90001                  0  2008      2021
# 4   AT1  AT13  AT130          90001                  0  2009      2021
#
#   BICYCLE BIKESHARING      BY_FOOT          CAR CARSHARING    MOTORBIKE  \
# 0       3           0           28           34          0            1
# 1       4           0           27           34          0            0
# 2       5           0           28           32          0            0
# 3       5           0           27           33          0            0
# 4     5,5           0  26,60000038  32,09999943          0  0,400000006
#
#   PUBLIC_TRANSPORT
# 0               34
# 1               35
# 2               35
# 3               35
# ...

# %%
df_2021.shape
# Out:
# (17, 14)

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NUTS1              17 non-null     object
#  1   NUTS2              17 non-null     object
#  2   NUTS3              17 non-null     object
#  3   DISTRICT_CODE      17 non-null     int64
#  4   SUB_DISTRICT_CODE  17 non-null     int64
#  5   YEAR               17 non-null     int64
#  6   REF_YEAR           17 non-null     int64
#  7   BICYCLE            17 non-null     object
#  8   BIKESHARING        17 non-null     object
#  9   BY_FOOT            17 non-null     object
#  10  CAR                17 non-null     object
#  11  CARSHARING         17 non-null     object
#  12  MOTORBIKE          17 non-null     object
#  13  PUBLIC_TRANSPORT   17 non-null     object
# dtypes: int64(4), object(10)
# memory usage: 2.0+ KB

# %%
# Convert relevant columns to numeric types
numeric_columns = ['BICYCLE', 'BIKESHARING', 'BY_FOOT', 'CAR', 'CARSHARING', 'MOTORBIKE', 'PUBLIC_TRANSPORT']
df_2021[numeric_columns] = df_2021[numeric_columns].apply(lambda x: x.str.replace(',', '.')).apply(pd.to_numeric).round(0).astype(int)

# Plot the development over the years
plt.figure(figsize=(10, 6))

for column in numeric_columns:
    plt.plot(df_2021['YEAR'], df_2021[column], label=column)

plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Development Over the Years')
plt.legend()
plt.show()
